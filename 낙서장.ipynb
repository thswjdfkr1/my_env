# %%
import numpy as np

# %%
stu1 = [100, 90, 30, 40]
stu2 = [90, 100, 20, 50]
stu3 = [50, 70, 100, 90]
stu4 = [40, 60, 90, 95]
stu5 = [60, 50, 60, 45]
X = np.array([stu1, stu2, stu3, stu4, stu5])
print(X)
# Out:
# [[100  90  30  40]
#  [ 90 100  20  50]
#  [ 50  70 100  90]
#  [ 40  60  90  95]
#  [ 60  50  60  45]]

# %%
import pandas as pd

# %%
stu_id = ['stu'+str(v+1) for v in range(5)]
pd.DataFrame(X, columns=['kor','eng', 'math', 'sci'], index=stu_id)
# Out:
#       kor  eng  math  sci
# stu1  100   90    30   40
# stu2   90  100    20   50
# stu3   50   70   100   90
# stu4   40   60    90   95
# stu5   60   50    60   45

# %%
from sklearn.decomposition import PCAelqh

# %%
pca4 = PCA(n_components=4) # 주성분 개수 = 4인 PCA 함수
pc4 = pca4.fit_transform(X)
pc_id = ['PC'+str(v+1) for v in range(4)]
pd.DataFrame(pc4,
columns=pc_id,
index=stu_id)
# Out:
#             PC1        PC2       PC3       PC4
# stu1 -51.817067  -1.485613  7.916656  2.472060
# stu2 -52.143411 -13.206153 -7.682111 -1.909825
# stu3  49.059551 -11.668766  8.304995 -2.006836
# stu4  52.455462  -5.150836 -7.536688  2.468144
# stu5   2.445464  31.511369 -1.002852 -1.023542

# %%
var_pc = np.var(pc4, axis=0)
pd.DataFrame(var_pc, index=pc_id, columns=['Variance'])
# Out:
#         Variance
# PC1  2113.667806
# PC2   266.453418
# PC3    49.693721
# PC4     4.185055

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaled_X = StandardScaler().fit_transform(X)
var_scaled_X = np.var(scaled_X, axis=0)
print("표준화된 데이터 분산의 합 =", np.sum(var_scaled_X))
# Out:
# 표준화된 데이터 분산의 합 = 4.0

# %%
father = np.array([152, 168, 170, 180, 183])
son = np.array([163, 166, 175, 178, 174])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(6, 3))
plt.scatter(father, son)
plt.show()

# %%
X = father.reshape(-1, 1)
y = son.reshape(-1, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression().fit(X, y)

# %%
print("Beta0 (절편) =", model.intercept_)
print("Beta1 (기울기) =", model.coef_)
# Out:
# Beta0 (절편) = [95.98924731]
# Beta1 (기울기) = [[0.44086022]]

# %%
pred = model.predict(X)
pred
# Out:
# array([[163.        ],
#        [170.05376344],
#        [170.93548387],
#        [175.34408602],
#        [176.66666667]])

# %%
import os, sys
my_path = '/content/notebooks'
os.symlink('/content/drive/MyDrive/Colab Notebooks/my_env', my_path)

sys.path.insert(0, my_path)

# %%
# !pip install --target=$my_path jdc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# WARNING: Target directory /content/notebooks/jdc already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/notebooks/jdc-0.0.9.dist-info already exists. Specify --upgrade to force replacement.

# %%
# !pip install --target=$my_path git+https://github.com/lee-ju/dslearn.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/lee-ju/dslearn.git to /tmp/pip-req-build-g4q2gfdf
#   Running command git clone --filter=blob:none --quiet https://github.com/lee-ju/dslearn.git /tmp/pip-req-build-g4q2gfdf
#   Resolved https://github.com/lee-ju/dslearn.git to commit 1041f504fe35a0ebaf9d3e40ca0a6e549216d732
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for dslearn: filename=dslearn-0.0.1-py3-none-any.whl size=3771 sha256=d451b747d18616907b99ecd92ae5bece9ee7143a728d3b777f94b2c952d208e3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jmu4vq7i/wheels/35/2c/0e/87d50df955494dcdbd6c07b6a1450aacd91b981126f31c76ce
# Successfully built dslearn
# ...
# WARNING: Target directory /content/notebooks/dslearn already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/notebooks/dslearn-0.0.1.dist-info already exists. Specify --upgrade to force replacement.

# %%
import pandas as pd
path = '/content/drive/MyDrive/Colab Notebooks/test1.csv'

# %%
data = pd.read_csv(path)

# %%
data
# Out:
#    x1  x2  x3
# 0   1   6  11
# 1   2   7  12
# 2   3   8  13
# 3   4   9  14
# 4   5  10  15

# %%
pi = 3.1415926
print("pi={:.2f}".format(pi))
# Out:
# pi=3.14

# %%
a = [1,2,3,4]
b = [5,6,7,8]
c= []
for z in zip(a,b):
  d= z[0] - z[1]
  c.append(d)
  print(c)
# Out:
# [-4]
# [-4, -4]
# [-4, -4, -4]
# [-4, -4, -4, -4]

# %%
a = [1,2,3,4]
for i, x in enumerate(a):
  print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
a = [1,2,3,4]
b = [5,6,7,8]
c = [9,10,11,12]
for i, z in enumerate(zip(a,b,c)):
  print(i, z)
# Out:
# 0 (1, 5, 9)
# 1 (2, 6, 10)
# 2 (3, 7, 11)
# 3 (4, 8, 12)

# %%
a = []
for i in range(0,6):
  a.append(i**2)
print(a)
# Out:
# [0, 1, 4, 9, 16, 25]

# %%
a = [ i**2 for i in range(0,6) if i>=3 ]
print(a)
# Out:
# [9, 16, 25]

# %%
a = [ 1 for _ in range(100)]  
len(a)
# Out:
# 100

# %%
a = [idx for idx, val in enumerate(range(10)) if val >= 5]
print(a)
# Out:
# [5, 6, 7, 8, 9]

# %%
a = [1,2,3,4,5]
for ai in a:
  if ai <= 3:
    b.append(ai)
  else: 
    b.append(-100)
b
# Out:
# [5, 6, 7, 8, 1, 2, 3, -100, -100]

# %%
a = [ai if ai <=3 else -100 for ai in a]
a
# Out:
# [1, 2, 3, -100, -100]

# %%
import numpy as np
a = np.array([1,2,3])
type(a)
# Out:
# numpy.ndarray

# %%
a = dict()
a['age'] = 17
a['weight'] = 60
a
a = {'age' : [17,20,20]}
a
# Out:
# {'age': [17, 20, 20]}
